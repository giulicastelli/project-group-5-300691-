# %% [markdown]
# # <span style='color: pink'>**AI Project - Guilds Dataset**</span>
# ### **Group 5**
# Giulia Castelli, Francesca Peppoloni and Anna Granzotto

# %% [markdown]
# ***

# %% [markdown]
# ### **Guilds**
# In the kingdom of Marendor, scholars strive to advance knowledge, and their goal is to enter the Master Guild, which reflects the influence of their discoveries. The council of Marendor values each scholar’s contribution and carefully assesses their research to predict the potential impact their work will have on the kingdom’s future progress. By analyzing various factors from the scholars' reports,the Academy aims to anticipate the guild assignment for each scholar, helping guide the kingdom's priorities in fostering groundbreaking discoveries. Use the dataset “guilds.csv”.

# %% [markdown]
# ### **1. EDA**

# %% [markdown]
# Exploratory Data Analysis (EDA) helps us to understand, clean, and gain insights from our
# dataset. EDA process steps are:
# 1. Understand Column Meanings
# 2. Check Data Integrity
# 3. Visualize Distributions
# 4. Correlation Heatmap

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
import requests

guilds_df = pd.read_csv('guilds.csv')
guilds_df.head()
# Out:
#    Fae_Dust_Reserve  Physical_Stamina  Mystical_Index  \
# 0          7.129337               0.0            28.0
# 1          5.465800               4.0            37.0
# 2          4.464708               0.0            41.0
# 3          8.214439               0.0            30.0
# 4          9.479264               0.0            49.0
#
#   Healer_consultation_Presence Elixir_veggies_consumption_Presence  \
# 0                      Present                              Absent
# 1                      Present                             Present
# 2                      Present                             Present
# 3                      Present                             Present
# 4                      Present                             Present
#
#    Mystic_Energy_Level Bolt_of_doom_Presence  Age_of_Wisdom  \
# 0             0.855643                Absent            8.0
# 1             0.628994                Absent           11.0
# ...

# %% [markdown]
# #### **1.1 Understand Columns Meanings**
#
# - **Fae_Dust_Reserve**:
#   - **Explanation**: Represents the subject’s reserve of mystical dust indicating magical potential.
#   - **Values**: Numeric
#
# - **Physical_Stamina**:
#   - **Explanation**: Indicates the subject's overall physical endurance and health.
#   - **Values**: Numeric
#
# - **Mystical_Index**:
#   - **Explanation**: Numeric representation of the subject's mystical power and well-being.
#   - **Values**: Numeric
#
# - **Healer_consultation_Presence**:
#   - **Explanation**: Indicates whether the subject has consulted a healer recently.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Elixir_veggies_consumption_Presence**:
#   - **Explanation**: Indicates whether the subject has consumed enchanted vegetables.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Mystic_Energy_Level**:
#   - **Explanation**: The level of mystical energy possessed by the subject.
#   - **Values**: Numeric
#
# - **Bolt_of_doom_Presence**:
#   - **Explanation**: Indicates whether the subject experienced a thunderstrike.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Age_of_Wisdom**:
#   - **Explanation**: The subject's age, indicating life experience.
#   - **Values**: Numeric
#
# - **High_willingness_Presence**:
#   - **Explanation**: Indicates whether the subject has a high willingness to engage in advanced magical practices.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Defense_spell_difficulty_Presence**:
#   - **Explanation**: Indicates if the subject has difficulty casting defense spells.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Doc_availability_challenge_Presence**:
#   - **Explanation**: Shows if there were any barriers preventing access to healers.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Mental_Wizardry**:
#   - **Explanation**: Represents the subject's mental health and wizardry capacity.
#   - **Values**: Numeric
#
# - **Potion_Power_Level**:
#   - **Explanation**: Represents the power or effectiveness of the potions used by the subject.
#   - **Values**: Numeric
#
# - **Dexterity_check_Presence**:
#   - **Explanation**: Indicates the subject's high dexterity.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Gold_Pouches_Per_Year**:
#   - **Explanation**: The subject’s annual income represented as gold pouches.
#   - **Values**: Numeric
#
# - **Wizardry_Skill**:
#   - **Explanation**: The subject’s proficiency in magical skills.
#   - **Values**: Numeric
#
# - **Spell_Mastering_Days**:
#   - **Explanation**: Number of days the subject has dedicated to mastering spells.
#   - **Values**: Numeric
#
# - **Level_of_Academic_Wisdom**:
#   - **Explanation**: The highest level of knowledge or wisdom achieved by the subject.
#   - **Values**: Numeric
#
# - **General_Health_Condition**:
#   - **Explanation**: An overall assessment of the subject's health status.
#   - **Values**: Numeric
#
# - **Fruits_of_eden_consumption_Presence**:
#   - **Explanation**: Indicates whether the subject consumes fruits from Eden.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Knight_physical_training_Presence**:
#   - **Explanation**: Indicates if the subject underwent knight-like physical training.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Royal_family_pressure_Presence**:
#   - **Explanation**: Indicates if the subject faces pressure from the royal family.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Dragon_Sight_Sharpness**:
#   - **Explanation**: Measures the subject’s visual acuity or ability to see mystical beings like dragons.
#   - **Values**: Numeric
#
# - **Guild_Membership**:
#   - **Explanation**: The guild or magical faction the subject will belong to.
#   - **Values**: Categorical, "Master_Guild", "No_Guild", "Apprentice_Guild" -> **target variable**
#
# - **Enchanted_Coin_Count**:
#   - **Explanation**: The number of enchanted coins the subject possesses.
#   - **Values**: Numeric
#
# - **Celestial_Alignment**:
#   - **Explanation**: Represents the alignment of the subject with celestial forces.
#   - **Values**: Numeric
#
# - **Knightly_Valor**:
#   - **Explanation**: The bravery and valor displayed by the subject.
#   - **Values**: Numeric
#
# - **Heavy_elixir_consumption_Presence**:
#   - **Explanation**: Indicates if the subject consumes heavy magical elixirs.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Stigmata_of_the_cursed_Presence**:
#   - **Explanation**: Indicates if the subject experienced a crisis or damage from magical or dark powers.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Dragon_status_Presence**:
#   - **Explanation**: Denotes whether the subject has the sign of the dragon.
#   - **Values**: Categorical, "Present" or "Absent".
#
# - **Rune_Power**:
#   - **Explanation**: Represents the power derived from magical runes by the subject.
#   - **Values**: Numeric

# %% [markdown]
# #### **1.2 Check Data Integrity**
# Check for missing values (NaN): This code defines a function, missing_values_table, which generates a table of missing values and their percentages for each column in a DataFrame.

# %%
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()

        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)

        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)

        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})

        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)

        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")

        # Return the dataframe with missing information
        return mis_val_table_ren_columns


missing_values_table(guilds_df)
# Out:
# Your selected dataframe has 31 columns.
# There are 31 columns that have missing values.
#                                      Missing Values  % of Total Values
# Celestial_Alignment                           25673               10.1
# Dragon_status_Presence                        25661               10.1
# Elixir_veggies_consumption_Presence           25570               10.1
# General_Health_Condition                      25569               10.1
# Level_of_Academic_Wisdom                      25560               10.1
# Dragon_Sight_Sharpness                        25539               10.1
# Bolt_of_doom_Presence                         25534               10.1
# Enchanted_Coin_Count                          25531               10.1
# Royal_family_pressure_Presence                25505               10.1
# Mystic_Energy_Level                           25503               10.1
# Knightly_Valor                                25502               10.1
# ...

# %% [markdown]
# **Missingno**
#
# Missingno  is  an  open-source  Python  library  designed  to  help  you  visualize  and  analyze missing  data  patterns  in  your  datasets.  It  offers  several  visualizations  and  tools  to  gain insights into the presence of missing values, including Matrix Plot, Heatmap and Bar Chart.

# %%
# Matrix Plot
import missingno as msno

msno.matrix(guilds_df, color=(1,0.6,0.8))
# Out:
# <Axes: >

# %% [markdown]
# **Types of Missingness:**
#
# - **Missing Completely at Random (MCAR):**
# In this case, the missing values on a given variable are not associated
# with  other  variables  in  the  dataset  or  with  the  variable  itself.  There  is  no
# discernible pattern or reason for the missing values. MCAR suggests that the absence of
# data is entirely random.
#
# - **Missing at Random (MAR):**
# MAR  occurs  when  the  missingness  is  not  entirely  random  but  can  be  explained  or
# predicted by other variables in the dataset. This means that there are variables where complete
# information is available, and the likelihood of missing data
# can be attributed to these variables.
#
# - **Missing Not at Random (MNAR):**
# In MNAR, the missingness depends on unobserved data or the value of the
# missing  data  itself.  In  other  words,  there  is  a  hidden  pattern  or  mechanism  causing
# certain values to be missing, and this pattern is not explained by the observed data alone.

# %% [markdown]
# **Final Conclusion:**
#
# The patterns and correlations observed suggest that most of the missingness in the dataset can be explained by relationships with other observed variables, classifying it primarily as `Missing at Random` (MAR). However, there are specific cases where some variables might exhibit missing values due to reasons inherent to the variables themselves, such as sensitivity or unavailability of the data, indicating a potential for `Missing Not at Random` (MNAR) in certain scenarios.

# %% [markdown]
# #### **1.3 Visualize Distributions**

# %% [markdown]
# The data type of the columns determines how they are analyzed. Numerical columns, such as continuous or discrete numbers, are visualized using boxplot analysis, while categorical columns, including strings or categories, are represented through countplot analysis. The target variable, `Guild_Membership`, is excluded from the list of columns being compared to ensure a clear focus on relationships between the target and other features. Additionally, only columns with non-empty and valid data types are included in the output. Columns with missing values or irrelevant data, such as those with all null values, are automatically excluded from the analysis.

# %% [markdown]
# **Numerical Columns:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Analyze the target variable against numerical columns
for column in guilds_df.select_dtypes(include=['int64', 'float64']).columns:
    if column != 'Guild_Membership':  # Exclude the target variable itself
        plt.figure(figsize=(6, 4))
        sns.boxplot(x='Guild_Membership', y=column, data=guilds_df)
        plt.title(f"Guild Membership vs {column}", fontsize=14)
        plt.xlabel("Guild Membership", fontsize=12)
        plt.ylabel(column, fontsize=12)
        plt.xticks(fontsize=10)
        plt.yticks(fontsize=10)
        plt.grid(axis='y')
        plt.tight_layout()
        plt.show()

# %% [markdown]
# **Categorical Columns:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Analyze the target variable against categorical columns
for column in guilds_df.select_dtypes(exclude=['int64', 'float64']).columns:
    if column != 'Guild_Membership':  # Exclude the target variable itself
        plt.figure(figsize=(6, 4))
        sns.countplot(x=guilds_df[column], hue=guilds_df['Guild_Membership'], 
                      order=guilds_df[column].value_counts().index)
        plt.title(f"{column} Distribution by Guild Membership", fontsize=14)
        plt.xlabel(column, fontsize=12)
        plt.ylabel("Count", fontsize=12)
        plt.legend(title="Guild Membership", fontsize=10)
        plt.xticks(fontsize=10, rotation=45)
        plt.yticks(fontsize=10)
        plt.grid(axis='y')
        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### **1.4 **Correlation Heatmap****

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Remove non-numeric columns
numeric_df = guilds_df.select_dtypes(include=['number'])

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(14, 12))  
sns.heatmap(
    correlation_matrix,
    annot=True,                 # Display correlation values
    fmt=".2f",                  
    cmap="coolwarm",            
    vmin=-1, vmax=1,            # Range of correlation values
    linewidths=0.5,             # Add grid lines
    cbar_kws={"shrink": 0.8}    
)

# Add title for label formatting
plt.title("Improved Correlation Heatmap of Guilds Dataset", fontsize=16)
plt.xticks(rotation=45, fontsize=10, ha='right')  
plt.yticks(fontsize=10)
plt.tight_layout()  
plt.show()

# %% [markdown]
# The correlation heatmap illustrates the relationships between numerical features in the dataset. Most features exhibit very low correlation values with one another and with the target variable, indicating weak linear relationships across the dataset. For example, "General_Health_Condition" shows the highest correlation (0.52) with "Physical_Stamina," but this is still moderate. The weak correlations with the target variable suggest that feature selection based on correlation would not improve the model. Consequently, all features are retained to ensure no potentially informative features are excluded, especially since the dataset may rely on complex, non-linear interactions for classification.

# %% [markdown]
# ---

# %% [markdown]
# ### **2. Preprocessing the dataset**

# %% [markdown]
# 1. Drop missing values (NaN) in `"Guild_Membership"`
# 2. Imput new values in the other columns: `Median`
# 3. Encode categorical features: `ONE-HOT ENCODE`
# 4. Fixing outliers: `Robust Scaling`

# %% [markdown]
# **Strategies we used to drop and imput data**
#
# Since Guild_Membership is the target variable for our analysis, it is crucial to ensure that this column contains no missing values. Rows with missing values in the target variable cannot be used effectively in supervised learning tasks, such as classification or regression, because the model would have no outcome to predict for those rows. Dropping rows with missing Guild_Membership values ensures that the dataset used for modeling contains complete and valid targets, which is essential for training and evaluation.
#
#  On the other hand, the other columns in the dataset serve as features, and their missing values can be imputed using appropriate methods, such as the median for numerical variables or the most frequent value for categorical variables. This approach allows you to retain as much data as possible while addressing missingness in a way that preserves the dataset's overall structure and variability. Imputation ensures that the information from the feature columns is not lost, thereby maximizing the size of the dataset and providing the model with the richest possible set of input data.
#
#  By combining these strategies—dropping rows with missing target values and imputing missing feature values—you maintain the integrity of the target variable while making the most of the available information in the features, ultimately creating a dataset that is both clean and robust for analysis.

# %% [markdown]
# #### **2.1 Drop missing values (NaN) in "Guild_Membership"**
# This code drops rows with missing values in the Guild_Membership column and calculates how many rows were removed.
#
# Since Guild_Membership is the target variable for our analysis, it is crucial to ensure that this column contains no missing values. Rows with missing values in the target variable cannot be used effectively in supervised learning tasks, such as classification or regression, because the model would have no outcome to predict for those rows. Dropping rows with missing Guild_Membership values ensures that the dataset used for modeling contains complete and valid targets, which is essential for training and evaluation.

# %%
initial_rows = len(guilds_df)
guilds_df = guilds_df.dropna(subset=['Guild_Membership'])
final_rows = len(guilds_df)

print(f"Initial rows: {initial_rows}")
print(f"Final rows: {final_rows}")
print(f"Rows dropped: {initial_rows - final_rows}")
# Out:
# Initial rows: 253680
# Final rows: 228233
# Rows dropped: 25447

# %% [markdown]
# In the next step, we can visualize what has been done: in this case, the column "Guild_Membership" doesn't have any more NaN values (white strips).

# %%
msno.matrix(guilds_df, color=(1,0.6,0.8))
# Out:
# <Axes: >

# %% [markdown]
# In order to see if we had lost an important amount of significant data, we have checked the percentage of rows dropped.

# %%
print("Percentage of Rows Dropped:", (25447 / len(guilds_df)) * 100, "%")
# Out:
# Percentage of Rows Dropped: 11.149570833315076 %

# %% [markdown]
# #### **2.2 Imputing new values**

# %% [markdown]
#  While for Guild_Membership we dropped its rows with missing values, on the other hand, the other columns in the dataset serve as features, and their missing values can be imputed using appropriate methods. This approach allows us to retain as much data as possible while addressing missingness in a way that preserves the dataset's overall structure and variability. Imputation ensures that the information from the feature columns is not lost, thereby maximizing the size of the dataset and providing the model with the richest possible set of input data.

# %% [markdown]
# **Substituting missing values in numerical columns**
#
# The **mean** is the average value of a dataset, calculated by summing all numbers and dividing by their count. It is sensitive to extreme values, which can significantly impact its value. On the other hand, the **median** represents the middle value of an ordered dataset and is resistant to outliers, making it more robust when dealing with extreme data points. In skewed distributions, the mean is influenced by the skew, while the median provides a more central and accurate representation.
#
# In our case, where the dataset is highly imbalanced, the `median` is a better choice for summarizing data. Since extreme values are likely present due to the imbalance, using the median ensures these outliers do not disproportionately affect the representation of the data, making it more reliable for analysis.

# %% [markdown]
# **Substituting missing values in categorical columns**
#
# For categorical columns, missing values are replaced with the `most frequent` value in the column, ensuring that no invalid or non-categorical entries are introduced.
# This is done through the SimpleImputer class from sklearn.impute, where the imputation strategy is set to 'most_frequent'.

# %%
from sklearn.impute import SimpleImputer

# Encode the target variable as numerical
guilds_df['Guild_Membership'] = guilds_df['Guild_Membership'].astype('category').cat.codes

# Separate features and target
X = guilds_df.drop(columns=['Guild_Membership'])  # Features
y = guilds_df['Guild_Membership']  # Target

# Identify numerical and categorical columns
numerical_cols = X.select_dtypes(include=['float64', 'int64']).columns
categorical_cols = X.select_dtypes(include=['object']).columns

# Create imputers
num_imputer = SimpleImputer(strategy='median')  # For numerical columns, replace missing values with the Median
cat_imputer = SimpleImputer(strategy='most_frequent')  # For categorical columns, replace with the most frequent value

# Impute numerical columns
X[numerical_cols] = num_imputer.fit_transform(X[numerical_cols])

# Impute categorical columns
X[categorical_cols] = cat_imputer.fit_transform(X[categorical_cols])

# Impute missing values in the target variable Guild_Membership
target_imputer = SimpleImputer(strategy='most_frequent')
y_imputed = target_imputer.fit_transform(y.values.reshape(-1, 1)).ravel()  # Flatten back to 1D

# Rejoin Guild_Membership to the features
X['Guild_Membership'] = y_imputed

# %% [markdown]
# In the next step, we can visualize what has been done: in this case, all the columns of the datatset do not have any more NaN values (white strips).

# %%
import missingno as msno
msno.matrix(X, color=(1,0.6,0.8))
# Out:
# <Axes: >

# %% [markdown]
# #### **2.3 Encoding categorical features: ONE-HOT ENCODE**

# %% [markdown]
# **One-hot encoding** is a method used to transform categorical features into numerical representations by creating new binary columns for each unique category in a feature. Each of these binary columns takes a value of 0 or 1, indicating the absence or presence of the corresponding category in a given row of the dataset.
#
# The target variable "Guild_Membership" is transformed into numerical labels through label encoding, where each unique category ("Master Guild", "Apprentice Guild" and "No Guild") is assigned a distinct integer value (0, 1 or 2) encoded into a single column.

# %%
# Apply one-hot encoding to categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# %% [markdown]
# We wanted to check what happened to a sample of categorical columns after one-hot encoding:

# %%
# Select four columns, including Guild_Membership
sample_columns = ['Guild_Membership', 'Royal_family_pressure_Presence_Present', 'High_willingness_Presence_Present','Bolt_of_doom_Presence_Present']  

# Display the first 5 rows of the selected columns
print("Sample of selected encoded columns:\n", X_encoded[sample_columns].head())
# Out:
# Sample of selected encoded columns:
#     Guild_Membership  Royal_family_pressure_Presence_Present  \
# 0                 1                                       1
# 1                 1                                       1
# 2                 2                                       0
# 3                 2                                       0
# 4                 2                                       1
#
#    High_willingness_Presence_Present  Bolt_of_doom_Presence_Present
# 0                                  1                              0
# 1                                  1                              0
# 2                                  1                              0
# 3                                  0                              0
# 4                                  0                              0

# %% [markdown]
# The code convert categorical features into binary indicators (0 or 1) for presence or absence, making them suitable for machine learning models.
# While the Guild_Membership column contains the numerical values 0, 1 and 2, which correspond to the categories "Master Guild", "No Guild" or "Apprentice Guild".

# %% [markdown]
# #### **2.4 Robust Scaling**

# %% [markdown]
# We decided to scale outliers instead of removing them because higher values in certain features are critical for distinguishing between guild memberships, such as master, no guild, or apprentice. Removing these values could lead to a loss of important information that contributes to classification, as the presence of extreme values might be significant indicators for certain categories in the target variable. By scaling, we reduce their numerical impact while preserving their relative importance within the dataset.

# %% [markdown]
# **Identification of outliers**

# %% [markdown]
# This code identifies outliers in numerical columns using the Interquartile Range (IQR) method. It calculates the IQR for each column, determines lower and upper bounds (1.5 times the IQR below Q1 and above Q3), and flags values outside these bounds as outliers. The code then identifies the number of outliers per column and the total rows containing outliers.

# %%
def identify_outliers_iqr(df, columns):
    outliers = pd.DataFrame(index=df.index)  # Create an empty DataFrame to track outliers
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Identify rows where the column values are outliers
        outliers[col] = (df[col] < lower_bound) | (df[col] > upper_bound)

    return outliers

# Identify numerical columns
numerical_cols = X_encoded.select_dtypes(include=['float64', 'int64']).columns

# Find outliers for numerical columns
outliers_iqr = identify_outliers_iqr(X_encoded, numerical_cols)

# Summarize the results
print(f"Number of outliers per column:\n{outliers_iqr.sum()}")
print(f"Total rows with any outliers: {outliers_iqr.any(axis=1).sum()}")
# Out:
# Number of outliers per column:
# Fae_Dust_Reserve             7213
# Physical_Stamina            37885
# Mystical_Index               8009
# Mystic_Energy_Level         13458
# Age_of_Wisdom                   0
# Mental_Wizardry             45775
# Potion_Power_Level              0
# Gold_Pouches_Per_Year           0
# Wizardry_Skill               3747
# Spell_Mastering_Days         9672
# Level_of_Academic_Wisdom        0
# General_Health_Condition     9736
# Dragon_Sight_Sharpness       7904
# Enchanted_Coin_Count            0
# Celestial_Alignment            42
# Knightly_Valor                410
# Rune_Power                   3335
# dtype: int64
# Total rows with any outliers: 101813

# %% [markdown]
# This code uses boxplots to visualize the distribution of specific features with many outliers. For each column of the sample (columns_to_plot), it creates a boxplot that highlights the spread of the data, including the median, quartiles, and potential outliers as black points outside the whiskers. The boxplots help identify the extent and distribution of outliers for the selected features.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot distributions for features with many outliers
columns_to_plot = ['Fae_Dust_Reserve', 'Physical_Stamina', 'Mystical_Index']
for col in columns_to_plot:
    sns.boxplot(data=X_encoded, x=col)
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# **Robust scaling**
#
# Robust Scaling is a scaling technique that adjusts numerical data by subtracting the median and scaling according to the interquartile range (IQR). It is particularly effective for datasets with outliers.
#
# Robust scaling is not sensitive to outliers because it uses the median (a robust measure of central tendency) and IQR (a robust measure of spread).
# This ensures that outliers do not overly influence the scaled values, which is critical for the dataset with features like Fae_Dust_Reserve and Physical_Stamina that have significant outliers.

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X_encoded[numerical_cols]), columns=numerical_cols)

# Replace original numerical features with scaled values
X_encoded[numerical_cols] = X_scaled

# %% [markdown]
# Check if we fixed outliers:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columns_to_plot = ['Fae_Dust_Reserve', 'Physical_Stamina', 'Mystical_Index']

# Updated boxplots after scaling 
for col in columns_to_plot:  
    plt.figure(figsize=(6, 4))
    sns.boxplot(data=X_scaled, x=col)
    plt.title(f"Boxplot of {col} (After Scaling)")
    plt.show()

# %% [markdown]
# **Comparison of the results**

# %% [markdown]
# - **Fae_Dust_Reserve**: Before scaling, the boxplot for Fae_Dust_Reserve shows a wide range of values, extending from 0 to around 50, with a significant number of outliers beyond 20. After robust scaling, the values are compressed into a smaller range, approximately between -1 and 6. The scaling reduces the effect of extreme values while preserving their presence. This adjustment makes the feature more comparable with others, especially when using machine learning models that are sensitive to the scale of numerical variables.
#
# - **Physical_Stamina**: Before scaling, the boxplot for Physical_Stamina displays a significant range of values, with the majority of data concentrated below 5 and numerous outliers extending up to approximately 30. After robust scaling, the data range is compressed, with the maximum value scaled down to approximately 14, and the central data range (the interquartile range) normalized around the median. While the relative positioning of outliers is preserved, their numerical impact is significantly reduced. This transformation highlights the range reduction from 0–30 to approximately 0–14, making the data more suitable for models sensitive to scale.
#
# - **Mystical_Index**: Before scaling, the boxplot for Mystical_Index exhibits a wide range of values, with the majority of the data concentrated between 20 and 40, while numerous outliers extend up to approximately 100. After robust scaling, the data range is compressed, with the maximum value scaled down to approximately 10, and the central data range (interquartile range) normalized around the median. Although the relative positioning of outliers is preserved, their numerical influence is significantly reduced. This transformation effectively adjusts the range from 20–100 to approximately -2–10, making the data more suitable for models sensitive to scale.

# %% [markdown]
# ---

# %% [markdown]
# ### **3. Regression, Classification or Clustering problem?**

# %% [markdown]
# **Define the Problem Type**
#
# Based on the dataset, this is a multi-class classification problem because the target variable `Guild_Membership` consists of discrete categories representing the guild each scholar belongs to ("Master Guild", "Apprentice Guild" and "No Guild"). The objective is to predict which guild each scholar will be assigned to based on their attributes.

# %% [markdown]
# **Select the models**
#
# Among the classication models we didn't chose neither KNN nor SVM since our dataset is too large and they wouldn't be efficient: KNN isn't robust while SVM has a slow training time. For this reason, we chose the other 3 type of models, even though some of them have certain limits:
#
# - Logistic Regression: it is an efficient and interpretable model suitable for large, high-dimensional datasets, making it a strong baseline for comparison. However, it assumes linear relationships, is sensitive to multicollinearity, and struggles with non-linear patterns or complex feature interactions without additional engineering.
#
# - Random forest: it is a robust model capable of capturing non-linear relationships and complex feature interactions. It effectively handles missing data and imbalanced datasets while providing insights into feature importance. However, it is computationally intensive, requires significant memory for large datasets, and is less interpretable compared to simpler models like logistic regression or decision trees.
#
# - CART Trees: they are simple and interpretable models that handle non-linear relationships and feature interactions effectively. They offer fast predictions and can manage missing data during splits. However, they are prone to overfitting without regularization, sensitive to small changes in the data, and generally less accurate compared to ensemble methods like Random Forest.

# %% [markdown]
# **Our prediction**
#
# We believe that Random Forest will have a better perfomance with respect to the others, while CART Trees and Logistic Regression will struggle a lot.

# %% [markdown]
# ---

# %% [markdown]
# ### **4. Implement the models**

# %% [markdown]
# ### **Logistic Regression**

# %% [markdown]
# ##### **1. Split the dataset into training, validation and test set**
# This code performs data splitting for logistic regression. First, it divides the dataset into training and test sets, ensuring class balance using stratified sampling. Then, it further splits the training set into smaller training and validation sets, maintaining the same class proportions. This process creates three subsets: one for training the model, one for tuning and validating it, and one for final testing, while preserving the class distribution across splits. The sizes of each subset are printed for verification.
#
# We used stratify to ensure that the class distribution in the target variable remains consistent across the training, validation, and test sets, maintaining the same proportions as in the original dataset.

# %%
# LOGISTIC REGRESSION

from sklearn.model_selection import train_test_split

# Step 1: Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# Step 2: Split the training set further into training and validation sets
X_train_split, X_validation, y_train_split, y_validation = train_test_split(
    X_train, y_train, test_size=0.25, random_state=42, stratify=y_train  # 20% of total becomes validation
)

# Output the sizes of the splits
print("Training set size:", len(X_train_split))
print("Validation set size:", len(X_validation))
print("Test set size:", len(X_test))
# Out:
# Training set size: 136939
# Validation set size: 45647
# Test set size: 45647

# %% [markdown]
# ##### **2. Analyzing the behavior of the default hyperparameters of Logistic Regression on the validation set:**
#
# This code trains a logistic regression model on the smaller training set, using default hyperparameters, and evaluates its performance on the validation set. It generates predictions for the validation data and calculates metrics like the confusion matrix and classification report, which include precision, recall, and F1-score. Finally, it prints the evaluation results, providing insights into the model's classification accuracy and performance across different classes.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

logistic_model = LogisticRegression()

# Train the model on the smaller training set
logistic_model.fit(X_train_split, y_train_split)

# Predict on the validation set
y_pred_validation = logistic_model.predict(X_validation)

# Evaluate model performance
conf_matrix = confusion_matrix(y_validation, y_pred_validation)
classification_rep = classification_report(y_validation, y_pred_validation)

# Print evaluation results
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_rep)
# Out:
# Confusion Matrix:
#  [[    0    51   782]
#  [    0   642  5706]
#  [    0   721 37745]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       833
#            1       0.45      0.10      0.17      6348
#            2       0.85      0.98      0.91     38466
#
#     accuracy                           0.84     45647
#    macro avg       0.44      0.36      0.36     45647
# weighted avg       0.78      0.84      0.79     45647
# /Users/giuli/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# **Comment of the results**
#
# The confusion matrix reveals that the model predicts Class 2 (the majority class) almost exclusively, while failing to correctly classify instances of Class 0 and Class 1. This is further reflected in the classification report, where precision, recall, and F1-score for Class 0 are all zero, and Class 1 scores are very low, indicating poor performance for these minority classes. In contrast, Class 2 achieves high precision (0.85), recall (0.98), and F1-score (0.91), dominating the overall accuracy of 0.84. However, the macro average scores are low, emphasizing the imbalanced class performance. The warnings highlight that precision is undefined for classes with no predicted samples (Class 0).

# %% [markdown]
# ##### **3. Use cross-validation to find the best set of hyperparameters**

# %% [markdown]
# This code performs hyperparameter tuning for logistic regression using GridSearchCV. It tests combinations of specified hyperparameters (C, solver, max_iter, and class_weight) to identify the best configuration for the model. Five-fold cross-validation is applied to evaluate the model's performance for each combination, using accuracy as the scoring metric. The best hyperparameters and their corresponding cross-validation accuracy are then extracted and printed. This approach ensures the model is optimized for performance while addressing potential issues like class imbalance and overfitting.

# %%
from sklearn.model_selection import GridSearchCV

# Define the hyperparameter grid
log_reg_params = {
    'C': [0.01, 0.1, 1.0, 10.0],  # Regularization strength
    'solver': ['lbfgs', 'saga'],  # Solvers for optimization
    'max_iter': [200, 300],       # Maximum iterations for convergence
    'class_weight': ['balanced'] # Handle class imbalance
}

# Set up GridSearchCV
log_reg_grid = GridSearchCV(
    estimator=LogisticRegression(random_state=42),
    param_grid=log_reg_params,
    cv=5,                        # 5-fold cross-validation
    scoring='accuracy',          # Use accuracy as the evaluation metric
    verbose=1,                   # Verbose output for detailed logs
    n_jobs=-1                    # Use all available processors
)

# Fit the grid search on the training set
log_reg_grid.fit(X_train_split, y_train_split)

# Extract the best hyperparameters and corresponding accuracy
best_params = log_reg_grid.best_params_
best_score = log_reg_grid.best_score_

# Print the best hyperparameters and cross-validation accuracy
print("Best Hyperparameters:", best_params)
print("Best Cross-Validation Accuracy:", best_score)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# /Users/giuli/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/giuli/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/giuli/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/giuli/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/giuli/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
# ...

# %% [markdown]
# **Hyperparameters Tuned**
#
# - `C`: it controls the strength of regularization, which penalizes large coefficients to prevent overfitting.
# Smaller values (e.g., C=0.01) imply stronger regularization, which helps when the model is overfitting.
# Larger values (e.g., C=10.0) reduce regularization, allowing the model to fit the training data more closely.
# Range Tested: [0.01, 0.1, 1.0, 10.0]
# Best Value: C=0.01 (stronger regularization worked better due to potential overfitting in the dataset).
#
# - `solver`: it determines the algorithm used to minimize the logistic regression loss function.
# Different solvers are suitable for different dataset sizes and types (e.g., dense or sparse features).
# lbfgs: Works well for small to medium-sized datasets and supports multinomial classification.
# saga: Scales well to large datasets and supports elastic net and L1 regularization.
# Range Tested: ['lbfgs', 'saga']
# Best Value: 'saga' (better convergence and performance on this dataset).
#
# - `max_iter`: it defines the maximum number of iterations the solver can take to converge.
# Higher values may be needed for large or complex datasets where convergence is slower.
# Range Tested: [200, 300]
# Best Value: 300 (the model converged adequately with this setting).
#
# - `class_weight`: it balances class weights to address imbalanced datasets by assigning higher weights to minority classes.
# 'balanced': Automatically adjusts weights inversely proportional to class frequencies.
# Range Tested: ['balanced'] (default approach for handling imbalance).
# Best Value: 'balanced' (ensured better treatment of minority classes in the imbalanced dataset).

# %% [markdown]
# ##### **4. Next Steps**
#
# Now that we have found the best hyperparameters, we retrained the Logistic Regression model using these values on the training set.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

logistic_model = LogisticRegression(
    C=0.01,              # Regularization strength
    class_weight='balanced',  # Handle class imbalance
    max_iter=300,        # Maximum iterations
    solver='saga',      # Optimization solver
    random_state=42      # Random state for reproducibility (optional)
)

# Train the model on the smaller training set
logistic_model.fit(X_train_split, y_train_split)

# Predict on the validation set
y_pred_validation = logistic_model.predict(X_validation)

# Evaluate model performance
conf_matrix = confusion_matrix(y_validation, y_pred_validation)
classification_rep = classification_report(y_validation, y_pred_validation)

# Print evaluation results
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_rep)
# Out:
# Confusion Matrix:
#  [[  368   246   219]
#  [ 2601  2492  1255]
#  [ 9879  5271 23316]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.03      0.44      0.05       833
#            1       0.31      0.39      0.35      6348
#            2       0.94      0.61      0.74     38466
#
#     accuracy                           0.57     45647
#    macro avg       0.43      0.48      0.38     45647
# weighted avg       0.84      0.57      0.67     45647
# /Users/giuli/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# **Comment of the results**
#
# After using the best hyperparameters, shows significant changes compared to the default hyperparameters. The overall accuracy decreased from 84% to 57%, indicating a drop in the model's ability to correctly classify the majority class. However, the performance for minority classes (Classes 0 and 1) improved. Class 0 now has a recall of 44% (compared to 0% previously), and Class 1 has better precision, recall, and F1-scores, suggesting the model is better handling the imbalanced dataset. Class 2, while still performing well, experienced a drop in precision and recall due to adjustments made to improve minority class predictions. The macro-average metrics improved slightly, reflecting better balance across all classes, but the weighted averages decreased, highlighting the trade-off between overall accuracy and fairness toward minority classes. The convergence warning indicates that the optimization process still needs adjustment to fully converge.

# %% [markdown]
# ##### **5. Test set**
#
# Now we use the test set, using the best hyperparameters founded before.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_auc_score

# Initialize Logistic Regression with the best hyperparameters
best_logistic_model = LogisticRegression(
    C=0.01,              # Best regularization strength
    class_weight='balanced',  # Handle class imbalance
    max_iter=300,        # Maximum iterations
    solver='saga',      # Optimization solver
    random_state=42
)

# Train the model on the full training set
best_logistic_model.fit(X_train, y_train)

# Predict on the test set
y_pred_test = best_logistic_model.predict(X_test)

# Evaluate model performance on the test set
test_conf_matrix = confusion_matrix(y_test, y_pred_test)
test_classification_rep = classification_report(y_test, y_pred_test)

# Predict probabilities for the test set
y_pred_proba = best_logistic_model.predict_proba(X_test)

# Compute ROC AUC (for binary classification or One-vs-Rest for multiclass)
roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')  # Adjust for binary/multiclass
print("Test ROC AUC:", roc_auc)

# Output evaluation results
print("\nConfusion Matrix:\n", test_conf_matrix)
print("\nClassification Report:\n", test_classification_rep)
# Out:
# Test ROC AUC: 0.7134335288603522
#
# Confusion Matrix:
#  [[  120   395   318]
#  [  802  3927  1619]
#  [ 3235  8625 26606]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.03      0.14      0.05       833
#            1       0.30      0.62      0.41      6348
#            2       0.93      0.69      0.79     38466
#
#     accuracy                           0.67     45647
#    macro avg       0.42      0.48      0.42     45647
# weighted avg       0.83      0.67      0.73     45647
# /Users/giuli/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# **Comment of the results**
#
# The results obtained with the test set, shows improvements in overall performance compared to the training set results, particularly in accuracy, which increased from 57% to 67%. For Class 0, precision and recall decreased significantly, dropping recall from 44% on the training set to 14% on the test set, highlighting that the model struggles to generalize for this class. However, for Class 1, recall improved from 39% to 62%, indicating better identification of this class in the test data, though precision slightly dropped. Class 2 maintained high performance, with a recall improvement from 61% to 69% and a stable precision of around 93%, which reflects the model's ability to handle the majority class effectively.
#
# The macro average metrics remain consistent, showing an overall balanced approach, while the weighted average metrics improved due to better accuracy and performance on the larger Class 2. The Test ROC AUC score of 0.71 suggests reasonable discrimination capability across all classes, even though the convergence warning persists.

# %% [markdown]
# ##### **6. Plotting the metrics: ROC-AUC curve and Confusion Matrix**

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, roc_curve, auc
import numpy as np

# Confusion Matrix Heatmap
plt.figure(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=test_conf_matrix, display_labels=['Class 0', 'Class 1', 'Class 2'])
disp.plot(cmap='Blues', ax=plt.gca())
plt.title("Confusion Matrix Heatmap")
plt.show()

# ROC Curve
plt.figure(figsize=(8, 6))
for i, class_name in enumerate(['Class 0', 'Class 1', 'Class 2']):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_name} (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC AUC Curve")
plt.legend()
plt.show()

# %% [markdown]
# **Observations**
#
# The first plot shows the confusion matrix as a heatmap, where the rows represent the actual classes and the columns represent the predicted classes. Class 2 dominates the true positive predictions with 26,606 correctly classified samples, whereas Class 1 has moderate performance with 3,927 correct predictions, and Class 0 has only 120 correctly classified samples. The imbalance is evident in the misclassifications, as most of Class 0 and Class 1 are predicted as Class 2.
#
# The second plot is the ROC AUC curve for the three classes (Class 0, Class 1, Class 2). Each curve represents the trade-off between the true positive rate (TPR) and false positive rate (FPR) for that class. Class 2 achieves the highest AUC score (0.77), followed by Class 1 (0.78), while Class 0 performs poorly with an AUC of 0.59. These curves suggest that the model struggles with Class 0 but performs better for Class 2.
#
# In conclusion, the confusion matrix and the ROC AUC curve together illustrate that the model performs well for Class 2 and moderately for Class 1 but fails to predict Class 0 effectively, due to the dataset's imbalance.

# %% [markdown]
# ---

# %% [markdown]
# ### **Random Forest**

# %% [markdown]
# ##### **1. Split the dataset into training, validation and test set**
# This code performs data splitting for random forest. First, it divides the dataset into training and test sets, ensuring class balance using stratified sampling. Then, it further splits the training set into smaller training and validation sets, maintaining the same class proportions. This process creates three subsets: one for training the model, one for tuning and validating it, and one for final testing, while preserving the class distribution across splits. The sizes of each subset are printed for verification.
#
# We used stratify to ensure that the class distribution in the target variable remains consistent across the training, validation, and test sets, maintaining the same proportions as in the original dataset.

# %%
# RANDOM FOREST

from sklearn.model_selection import train_test_split

# Step 1: Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# Step 2: Split the training set further into training and validation sets
X_train_split, X_validation, y_train_split, y_validation = train_test_split(
    X_train, y_train, test_size=0.25, random_state=42, stratify=y_train  # 20% of total becomes validation
)

# Output the sizes of the splits
print("Training set size:", len(X_train_split))
print("Validation set size:", len(X_validation))
print("Test set size:", len(X_test))
# Out:
# Training set size: 136939
# Validation set size: 45647
# Test set size: 45647

# %% [markdown]
# ##### **2. Analyzing the behavior of the default hyperparameters of Random Forest on the validation set:**
#
# This code trains a random forest model on the smaller training set, using default hyperparameters, and evaluates its performance on the validation set. It generates predictions for the validation data and calculates metrics like the confusion matrix and classification report, which include precision, recall, and F1-score. Finally, it prints the evaluation results, providing insights into the model's classification accuracy and performance across different classes.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report

random_forest_model = RandomForestClassifier()

# Train the model on the smaller training set
random_forest_model.fit(X_train_split, y_train_split)

# Predict on the validation set
y_pred_validation = random_forest_model.predict(X_validation)

# Evaluate model performance
conf_matrix = confusion_matrix(y_validation, y_pred_validation)
classification_rep = classification_report(y_validation, y_pred_validation)

# Print evaluation results
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_rep)
# Out:
# Confusion Matrix:
#  [[    0    52   781]
#  [    0   547  5801]
#  [    0   523 37943]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       833
#            1       0.49      0.09      0.15      6348
#            2       0.85      0.99      0.91     38466
#
#     accuracy                           0.84     45647
#    macro avg       0.45      0.36      0.35     45647
# weighted avg       0.79      0.84      0.79     45647
# /Users/giuli/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# **Comment of the results**
#
# This output indicates poor model performance for classes 0 and 1, with no correct predictions for class 0 and very limited recall for class 1 (8%). Class 2 is predicted well, with a high recall of 99% and a precision of 85%, dominating the weighted averages. The overall accuracy is 84%, driven largely by the model's strong focus on class 2. The macro average metrics (precision, recall, f1-score) are low, reflecting poor performance on the minority classes. Warnings highlight undefined precision for class 0 due to no predictions being made for it.

# %% [markdown]
# ##### **3. Use cross-validation to find the best set of hyperparameters**

# %% [markdown]
# This code performs hyperparameter tuning for a Random Forest model using GridSearchCV. It defines a grid of hyperparameters, including the number of trees (n_estimators), maximum depth (max_depth), minimum samples required for splits and leaves (min_samples_split, min_samples_leaf), and class weights (class_weight). The grid search uses 3-fold cross-validation to evaluate combinations of these parameters based on the macro F1-score. The best set of hyperparameters and the corresponding cross-validation score are then extracted and printed. This approach ensures the model is optimized for imbalanced data and generalizes well.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# Define the hyperparameter grid for Random Forest
random_forest_params = {
    'n_estimators': [100, 200],       # Number of trees
    'max_depth': [None, 10],           # Maximum depth of trees
    'min_samples_split': [2, 5],       # Minimum number of samples to split an internal node
    'min_samples_leaf': [1, 2],         # Minimum number of samples required in a leaf node
    'class_weight': ['balanced', 'balanced_subsample']  # Handle class imbalance
}

# Set up GridSearchCV
random_forest_grid = GridSearchCV(
    estimator=RandomForestClassifier(random_state=42),
    param_grid=random_forest_params,
    cv=3,                        # 3-fold cross-validation
    scoring='f1_macro',  # Optimize for macro F1-score
    verbose=1,                   # Verbose output for detailed logs
    n_jobs=-1                    # Use all available processors
)

# Fit the grid search on the training set
random_forest_grid.fit(X_train_split, y_train_split)

# Extract the best hyperparameters and corresponding accuracy
random_forest_best_params = random_forest_grid.best_params_
random_forest_best_score = random_forest_grid.best_score_

# Print the best hyperparameters and cross-validation accuracy
print("Best Hyperparameters (Random Forest):", random_forest_best_params)
print("Best Cross-Validation Accuracy (Random Forest):", random_forest_best_score)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# /Users/giuli/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best Hyperparameters (Random Forest): {'class_weight': 'balanced_subsample', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best Cross-Validation Accuracy (Random Forest): 0.4119198278248624

# %% [markdown]
# **Hyperparameters Tuned**
#
# - `n_estimators`: This parameter specifies the number of trees in the forest. A higher number of trees usually improves performance but increases computational cost.
# Smaller values (e.g., n_estimators=100) allow faster training, while larger values (e.g., n_estimators=200) can provide better generalization at the cost of longer training time.
# Range Tested: [100, 200]
# Best Value: 100 (fewer trees were sufficient for this dataset without significant loss in performance).
#
# - `max_depth`: It controls the maximum depth of each tree in the forest. Limiting the depth prevents overfitting, especially with noisy or complex datasets.
# max_depth=None allows trees to grow fully until all leaves are pure or contain fewer samples than the minimum split requirement.
# Range Tested: [None, 10]
# Best Value: 10 (a limited tree depth avoided overfitting and provided better generalization).
#
# - `min_samples_split`: Defines the minimum number of samples required to split an internal node. Higher values reduce overfitting by ensuring splits occur only when a node contains enough data.
# Range Tested: [2, 5]
# Best Value: 2 (allowed the model to split nodes flexibly, capturing important patterns).
#
# - `min_samples_leaf`: Specifies the minimum number of samples required in a leaf node. Higher values can smooth the model by enforcing larger leaf sizes, preventing overfitting.
# Range Tested: [1, 2]
# Best Value: 1 (smaller leaf sizes allowed the model to capture detailed relationships in the data).
#
# - `class_weight`: Balances the class weights to handle imbalanced datasets by assigning higher weights to minority classes.
# balanced: Adjusts weights inversely proportional to class frequencies in the entire dataset.
# balanced_subsample: Adjusts weights based on class frequencies in the bootstrap sample used for each tree.
# Range Tested: ['balanced', 'balanced_subsample']
# Best Value: 'balanced_subsample' (improved handling of imbalanced classes during training without overemphasizing minority classes).

# %% [markdown]
# ##### **4. Next Steps**
# Now that we have found the best hyperparameters, we retrain the Random Forest model using these values on the training set.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report

# Initialize Random Forest with the best hyperparameters
best_random_forest_model = RandomForestClassifier(
    n_estimators=100,                # Best number of trees
    max_depth=10,                  # No limit on tree depth
    min_samples_split=2,             # Minimum samples required to split an internal node
    min_samples_leaf=1,              # Minimum samples in a leaf node
    class_weight='balanced_subsample',  # Handle class imbalance
    random_state=42                  # Random state for reproducibility
)

# Train the model on the smaller training set
best_random_forest_model.fit(X_train_split, y_train_split)

# Predict on the validation set
y_pred_validation_rf = best_random_forest_model.predict(X_validation)

# Evaluate model performance
conf_matrix_rf = confusion_matrix(y_validation, y_pred_validation_rf)
classification_rep_rf = classification_report(y_validation, y_pred_validation_rf)

# Print evaluation results
print("\nConfusion Matrix (Random Forest with Best Params):\n", conf_matrix_rf)
print("\nClassification Report (Random Forest with Best Params):\n", classification_rep_rf)
# Out:
# Confusion Matrix (Random Forest with Best Params):
#  [[   41   491   301]
#  [  284  4498  1566]
#  [ 1268 11178 26020]]
#
# Classification Report (Random Forest with Best Params):
#                precision    recall  f1-score   support
#
#            0       0.03      0.05      0.03       833
#            1       0.28      0.71      0.40      6348
#            2       0.93      0.68      0.78     38466
#
#     accuracy                           0.67     45647
#    macro avg       0.41      0.48      0.41     45647
# weighted avg       0.83      0.67      0.72     45647

# %% [markdown]
# **Comment of the results**
#
# We notice an improvement in the performance of the Random Forest model after applying the best hyperparameters. For class 0, precision and recall remain very low, indicating challenges in correctly predicting this minority class. However, for class 1, there is a notable improvement in recall, increasing from 0.08 to 0.71, which reflects a better ability to identify true instances of class 1. Similarly, precision for class 2 remains high, but recall decreases slightly, leading to a more balanced performance across classes. The overall accuracy drops slightly from 0.84 to 0.67 due to the model now prioritizing balanced predictions over the majority class. The macro-average precision and recall show marginal changes, but the weighted averages highlight improved handling of class imbalances, particularly for class 1. This reflects the positive impact of the hyperparameter tuning in achieving better trade-offs across the classes.

# %% [markdown]
# ##### **5. Test set**
#
# Now we use the test set, using the best hyperparameters founded before.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_auc_score

# Initialize Random Forest with the best hyperparameters
best_random_forest_model = RandomForestClassifier(
    n_estimators=100,                # Best number of trees
    max_depth=10,                  # No limit on tree depth
    min_samples_split=2,             # Minimum samples required to split an internal node
    min_samples_leaf=1,              # Minimum samples in a leaf node
    class_weight='balanced_subsample',  # Handle class imbalance
    random_state=42                  # Random state for reproducibility
)

# Train the model on the full training set
best_random_forest_model.fit(X_train, y_train)

# Predict on the test set
y_pred_test_rf = best_random_forest_model.predict(X_test)

# Evaluate model performance on the test set
test_conf_matrix_rf = confusion_matrix(y_test, y_pred_test_rf)
test_classification_rep_rf = classification_report(y_test, y_pred_test_rf)

# Predict probabilities for the test set
y_pred_proba = best_random_forest_model.predict_proba(X_test)

# Compute ROC AUC (for binary classification or One-vs-Rest for multiclass)
roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')  # Adjust for binary/multiclass
print("Test ROC AUC:", roc_auc)

# Output evaluation results
print("\nConfusion Matrix (Random Forest):\n", test_conf_matrix_rf)
print("\nClassification Report (Random Forest):\n", test_classification_rep_rf)
# Out:
# Test ROC AUC: 0.7412707814794314
#
# Confusion Matrix (Random Forest):
#  [[   59   474   300]
#  [  381  4497  1470]
#  [ 1856 10762 25848]]
#
# Classification Report (Random Forest):
#                precision    recall  f1-score   support
#
#            0       0.03      0.07      0.04       833
#            1       0.29      0.71      0.41      6348
#            2       0.94      0.67      0.78     38466
#
#     accuracy                           0.67     45647
#    macro avg       0.42      0.48      0.41     45647
# weighted avg       0.83      0.67      0.72     45647

# %% [markdown]
# **Comment of the results**
#
# The second output evaluates the Random Forest model with the best hyperparameters on the test set. Compared to the training set, the performance is consistent overall, with a maintained accuracy of 0.67 and similar precision and recall values. For class 0, the precision and recall remain low, showing the continued difficulty in predicting this minority class, but there is a slight improvement in recall from 0.05 to 0.07. For class 1, recall remains high at 0.71, while precision is relatively stable at 0.29, indicating the model's ability to identify true positives effectively in this class. Class 2 maintains high precision (0.94) but slightly reduced recall (0.67 compared to 0.68 on the training set). The weighted averages are consistent, reflecting balanced performance across the dataset. The Test ROC AUC of 0.741 further confirms the model's ability to distinguish between classes, particularly for the majority class, demonstrating robustness and generalization from the training to the test data.

# %% [markdown]
# ##### **Plotting the metrics: ROC-AUC curve and Confusion Matrix**

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, roc_curve, auc
import numpy as np

# Confusion Matrix Heatmap
plt.figure(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=test_conf_matrix_rf, display_labels=['Class 0', 'Class 1', 'Class 2'])
disp.plot(cmap='Blues', ax=plt.gca())
plt.title("Confusion Matrix Heatmap")
plt.show()

# ROC Curve
plt.figure(figsize=(8, 6))
for i, class_name in enumerate(['Class 0', 'Class 1', 'Class 2']):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_name} (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC AUC Curve")
plt.legend()
plt.show()

# %% [markdown]
# **Observations**
#
# The confusion matrix heatmap shows the performance of the random forest model on the test set. Class 2 dominates in terms of correctly predicted samples with 25,848 true positives, while classes 0 and 1 have far fewer correct predictions, indicating difficulty in handling the minority classes. Misclassifications for class 0 are spread between being predicted as class 1 or class 2, while for class 1, a significant portion is misclassified as class 2.
#
# The ROC AUC curve provides an evaluation of the model's ability to distinguish between classes. The AUC values for class 2 (0.79) and class 1 (0.79) are relatively higher, suggesting better performance in identifying these classes. However, the AUC for class 0 is lower (0.65), reflecting the model's struggle to identify this class accurately. The curves indicate moderate predictive power overall, with room for improvement, especially for the minority classes.
#
# In conclusion, the model performs well for class 2, which has the most samples, but struggles with the minority classes (0 and 1). While the ROC AUC scores show moderate performance, the confusion matrix highlights the challenge in balancing predictions across all classes, emphasizing the need for improved handling of minority classes.

# %% [markdown]
# ---

# %% [markdown]
# ### **CART Trees**

# %% [markdown]
# ##### **1. Split the dataset into training, validation and test set**
# This code performs data splitting for CART trees. First, it divides the dataset into training and test sets, ensuring class balance using stratified sampling. Then, it further splits the training set into smaller training and validation sets, maintaining the same class proportions. This process creates three subsets: one for training the model, one for tuning and validating it, and one for final testing, while preserving the class distribution across splits. The sizes of each subset are printed for verification.
#
# We used stratify to ensure that the class distribution in the target variable remains consistent across the training, validation, and test sets, maintaining the same proportions as in the original dataset.

# %%
# CART TREES 

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# Step 1: Split the data into training and test sets with stratification
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# Step 2: Split the training set further into training and validation sets with stratification
X_train_split, X_validation, y_train_split, y_validation = train_test_split(
    X_train, y_train, test_size=0.25, random_state=42, stratify=y_train  # 20% of total becomes validation
)

# Output the sizes of the splits
print("Training set size:", len(X_train_split))
print("Validation set size:", len(X_validation))
print("Test set size:", len(X_test))
# Out:
# Training set size: 136939
# Validation set size: 45647
# Test set size: 45647

# %% [markdown]
# ##### **2. Analyzing the behavior of the default hyperparameters of CART Trees on the validation set:**
#
# This code trains a CART trees model on the smaller training set, using default hyperparameters, and evaluates its performance on the validation set. It generates predictions for the validation data and calculates metrics like the confusion matrix and classification report, which include precision, recall, and F1-score. Finally, it prints the evaluation results, providing insights into the model's classification accuracy and performance across different classes.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report

# Initialize Decision Tree (CART) model with default parameters
cart_model = DecisionTreeClassifier()

# Train the model on the smaller training set
cart_model.fit(X_train_split, y_train_split)

# Predict on the validation set
y_pred_validation_cart = cart_model.predict(X_validation)

# Evaluate model performance on the validation set
conf_matrix_cart = confusion_matrix(y_validation, y_pred_validation_cart)
classification_rep_cart = classification_report(y_validation, y_pred_validation_cart)

# Output evaluation results
print("\nConfusion Matrix (CART):\n", conf_matrix_cart)
print("\nClassification Report (CART):\n", classification_rep_cart)
# Out:
# Confusion Matrix (CART):
#  [[   29   189   615]
#  [  175  1774  4399]
#  [  723  4989 32754]]
#
# Classification Report (CART):
#                precision    recall  f1-score   support
#
#            0       0.03      0.03      0.03       833
#            1       0.26      0.28      0.27      6348
#            2       0.87      0.85      0.86     38466
#
#     accuracy                           0.76     45647
#    macro avg       0.38      0.39      0.39     45647
# weighted avg       0.77      0.76      0.76     45647

# %% [markdown]
# **Comment of the results**
#
# The confusion matrix shows that the CART model struggles with correctly predicting minority classes (Class 0 and Class 1), as most predictions are concentrated in Class 2. The classification report highlights a high precision and recall for Class 2, indicating the model performs well for the majority class. However, both precision and recall are very low for Classes 0 and 1, resulting in a poor f1-score. The overall accuracy is 76%, primarily driven by the correct classification of Class 2, while the macro average metrics reveal the model's inability to balance performance across all classes.

# %% [markdown]
# ##### **3. Use cross-validation to find the best set of hyperparameters**

# %% [markdown]
# This code performs hyperparameter tuning for a Decision Tree (CART) model using grid search. It defines a grid of hyperparameters, including the splitting criterion (gini or entropy), maximum tree depth, minimum samples for splitting and leaf nodes, and class weight handling (balanced for imbalanced data). GridSearchCV evaluates combinations of these hyperparameters using 3-fold cross-validation, optimizing for the macro F1-score. After fitting the training data, the code extracts and prints the best hyperparameters and their corresponding cross-validation score.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Define the hyperparameter grid for Decision Tree (CART)
cart_params = {
    'criterion': ['gini', 'entropy'],     # Splitting criteria
    'max_depth': [None, 10, 20],          # Maximum depth of trees
    'min_samples_split': [2, 5, 10],      # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],        # Minimum number of samples required in a leaf node
    'class_weight': ['balanced']          # Handle class imbalance
}

# Set up GridSearchCV
cart_grid = GridSearchCV(
    estimator=DecisionTreeClassifier(random_state=42),
    param_grid=cart_params,
    cv=3,                        # 3-fold cross-validation
    scoring='f1_macro',          # Optimize for macro F1-score
    verbose=1,                   # Verbose output for detailed logs
    n_jobs=-1                    # Use all available processors
)

# Fit the grid search on the training set
cart_grid.fit(X_train_split, y_train_split)

# Extract the best hyperparameters and corresponding accuracy
cart_best_params = cart_grid.best_params_
cart_best_score = cart_grid.best_score_

# Print the best hyperparameters and cross-validation accuracy
print("Best Hyperparameters (CART):", cart_best_params)
print("Best Cross-Validation Accuracy (CART):", cart_best_score)
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# Best Hyperparameters (CART): {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best Cross-Validation Accuracy (CART): 0.38437166681617035

# %% [markdown]
# **Hyperparameters Tuned**
#
# - `criterion`: Determines the function used to measure the quality of a split.
# gini: Uses the Gini impurity to evaluate splits, favoring purity in child nodes.
# entropy: Uses information gain to evaluate splits, slightly more computationally intensive than Gini but can produce similar results.
# Range Tested: ['gini', 'entropy']
# Best Value: 'gini' (simpler and performed better on this dataset).
#
# - `max_depth`: Controls the maximum depth of the tree. Limiting the depth prevents overfitting by ensuring the tree doesn’t become overly complex.
# None: Allows the tree to grow until all leaves are pure or contain fewer samples than min_samples_split.
# Range Tested: [None, 10, 20]
# Best Value: 20 (offered a balance between capturing complexity and avoiding overfitting).
#
# - `min_samples_split`: Specifies the minimum number of samples required to split an internal node. Higher values prevent the tree from growing too deep, reducing overfitting.
# Range Tested: [2, 5, 10]
# Best Value: 2 (allowed the model to split nodes flexibly, capturing key patterns).
#
# - `min_samples_leaf`: Defines the minimum number of samples required to be in a leaf node. Larger values result in smoother models by reducing tree complexity.
# Range Tested: [1, 2, 4]
# Best Value: 1 (smaller leaf sizes allowed the tree to model detailed patterns in the data).
#
# - `class_weight`: Balances the class weights to handle imbalanced datasets by assigning higher weights to minority classes.
# 'balanced': Adjusts weights inversely proportional to class frequencies.
# Range Tested: ['balanced'] (default approach to address imbalance).
# Best Value: 'balanced' (ensured better representation of minority classes in the imbalanced dataset).

# %% [markdown]
# ##### **4. Next Steps**
# Now that we have found the best hyperparameters are identified, retrain the CART Tree model using these values on the training set.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report

# Initialize Decision Tree (CART) with the best hyperparameters
best_cart_model = DecisionTreeClassifier(
    criterion='gini',               # Splitting criterion
    max_depth=20,                   # Maximum depth of the tree
    min_samples_split=2,            # Minimum samples required to split an internal node
    min_samples_leaf=1,             # Minimum samples required in a leaf node
    class_weight='balanced',        # Handle class imbalance
    random_state=42                 # Random state for reproducibility
)

# Train the model on the smaller training set
best_cart_model.fit(X_train_split, y_train_split)

# Predict on the validation set
y_pred_validation_cart = best_cart_model.predict(X_validation)

# Evaluate model performance
conf_matrix_cart = confusion_matrix(y_validation, y_pred_validation_cart)
classification_rep_cart = classification_report(y_validation, y_pred_validation_cart)

# Print evaluation results
print("\nConfusion Matrix (CART with Best Params):\n", conf_matrix_cart)
print("\nClassification Report (CART with Best Params):\n", classification_rep_cart)
# Out:
# Confusion Matrix (CART with Best Params):
#  [[   58   318   457]
#  [  612  2639  3097]
#  [ 2633  7685 28148]]
#
# Classification Report (CART with Best Params):
#                precision    recall  f1-score   support
#
#            0       0.02      0.07      0.03       833
#            1       0.25      0.42      0.31      6348
#            2       0.89      0.73      0.80     38466
#
#     accuracy                           0.68     45647
#    macro avg       0.38      0.41      0.38     45647
# weighted avg       0.78      0.68      0.72     45647

# %% [markdown]
# **Comment of the results**
#
# The results, using the best set of hyperparameters, show a slight improvement in performance for minority classes (Classes 0 and 1) compared to the default hyperparameters. Class 0 has a marginally better recall (from 0.03 to 0.07), and Class 1 sees a notable increase in recall (from 0.28 to 0.42), resulting in a higher f1-score for these classes. However, there is a trade-off for Class 2, where recall drops slightly from 0.85 to 0.73, though its precision remains high. The overall accuracy decreases from 76% to 68%, indicating a more balanced performance across all classes. The macro averages remain low, showing the difficulty in achieving balanced predictions across classes, but the weighted averages reflect improved handling of class imbalance.

# %% [markdown]
# ##### **5. Test set**
# Now we use the test set, using the best hyperparameters founded before.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_auc_score

# Initialize Decision Tree (CART) with the best hyperparameters
best_cart_model = DecisionTreeClassifier(
    criterion='gini',               # Splitting criterion
    max_depth=20,                   # Maximum depth of the tree
    min_samples_split=2,            # Minimum samples required to split an internal node
    min_samples_leaf=1,             # Minimum samples required in a leaf node
    class_weight='balanced',        # Handle class imbalance
    random_state=42                 # Random state for reproducibility
)

# Train the model on the full training set
best_cart_model.fit(X_train, y_train)

# Predict on the test set
y_pred_test_cart = best_cart_model.predict(X_test)

# Evaluate model performance on the test set
test_conf_matrix_cart = confusion_matrix(y_test, y_pred_test_cart)
test_classification_rep_cart = classification_report(y_test, y_pred_test_cart)

# Predict probabilities for the test set
y_pred_proba = best_cart_model.predict_proba(X_test)

# Compute ROC AUC (for binary classification or One-vs-Rest for multiclass)
roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')  # Adjust for binary/multiclass
print("Test ROC AUC:", roc_auc)

# Output evaluation results
print("\nConfusion Matrix (CART):\n", test_conf_matrix_cart)
print("\nClassification Report (CART):\n", test_classification_rep_cart)
# Out:
# Test ROC AUC: 0.5923340151608303
#
# Confusion Matrix (CART):
#  [[   93   300   440]
#  [  839  2797  2712]
#  [ 3191  8127 27148]]
#
# Classification Report (CART):
#                precision    recall  f1-score   support
#
#            0       0.02      0.11      0.04       833
#            1       0.25      0.44      0.32      6348
#            2       0.90      0.71      0.79     38466
#
#     accuracy                           0.66     45647
#    macro avg       0.39      0.42      0.38     45647
# weighted avg       0.79      0.66      0.71     45647

# %% [markdown]
# **Comment of the results**
#
# The results, evaluated on the test set, demonstrate a slightly lower performance compared to the training set, indicating some generalization challenges. Class 0 shows a slight improvement in recall (from 0.07 to 0.11), but its overall precision and f1-score remain very low due to poor class separability. Class 1 maintains similar precision but improves in recall (from 0.42 to 0.44), resulting in a marginally higher f1-score. Class 2 experiences a slight decrease in recall (from 0.73 to 0.71), but its high precision (0.90) keeps its f1-score relatively stable. The overall accuracy drops slightly from 68% to 66%, reflecting the added complexity of handling unseen data. The macro average remains low, showing challenges in balancing predictions for minority classes, while the weighted average indicates the model's overall focus on the dominant class (Class 2). The Test ROC AUC of 0.59 further highlights the limited separability between classes, emphasizing areas for further model refinement.

# %% [markdown]
# ##### **Plotting the metrics: ROC-AUC curve and Confusion Matrix**

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, roc_curve, auc
import numpy as np

# Confusion Matrix Heatmap
plt.figure(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=test_conf_matrix_cart, display_labels=['Class 0', 'Class 1', 'Class 2'])
disp.plot(cmap='Blues', ax=plt.gca())
plt.title("Confusion Matrix Heatmap")
plt.show()

# ROC Curve
plt.figure(figsize=(8, 6))
for i, class_name in enumerate(['Class 0', 'Class 1', 'Class 2']):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_name} (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC AUC Curve")
plt.legend()
plt.show()

# %% [markdown]
# **Observations**
#
# The confusion matrix for the CART model shows the distribution of predictions across the three classes. Class 2 has the highest recall, meaning the model performs well in identifying it, while Class 0 and Class 1 have significantly lower recall, indicating poor performance in predicting those classes. Precision for Class 2 is high, but for Class 0 and Class 1, it is very low.
#
# The ROC AUC curve reflects the model's ability to distinguish between the classes. Class 2 has the highest AUC of 0.63, showing the model is moderately good at distinguishing this class from the others. However, the AUC for Class 0 is very low at 0.52, close to random guessing, while Class 1 has an intermediate AUC of 0.63.
#
# Together, the results highlight that the CART model struggles with imbalanced classes, performing well for the majority class (Class 2) but poorly for the minority classes (Class 0 and Class 1). This imbalance impacts overall accuracy and the model's ability to generalize effectively across all classes.

# %% [markdown]
# ---

# %% [markdown]
# ##### **Comparison of the different models**

# %% [markdown]
# **`Logistic Regression`**
#
# **Confusion Matrix**
# - Strengths:
# Performs relatively well for Class 2 (majority class), with a significant number of correctly predicted samples.
# Achieves a reasonable balance between precision and recall for Class 1.
# - Weaknesses:
# Struggles with Class 0, showing very poor precision and recall.
# Misclassifies many Class 1 and Class 0 samples as Class 2 due to dataset imbalance.
#
# **ROC AUC**
# - Class 0: AUC = 0.59, indicating poor discrimination for the minority class.
# - Class 1: AUC = 0.78, which is moderate and suggests the model can distinguish Class 1 to some extent.
# - Class 2: AUC = 0.77, which is decent, reflecting good performance for the majority class.
#
# **`Random Forest`**
#
# **Confusion Matrix**
# - Strengths:
# Handles the majority class (Class 2) well, with high recall and precision.
# Outperforms Logistic Regression slightly in terms of recall for Class 1.
# - Weaknesses:
# Poor handling of Class 0, with no correct predictions for this class.
# Still has a noticeable bias towards Class 2.
#
# **ROC AUC**
# - Class 0: AUC = 0.65, slightly better than Logistic Regression, but still insufficient for minority class discrimination.
# - Class 1: AUC = 0.79, slightly better than Logistic Regression.
# - Class 2: AUC = 0.79, indicating good performance for the majority class.
#
# **`CART Decision Tree`**
#
# **Confusion Matrix**
# - Strengths:
# Identifies a significant number of samples in the majority class (Class 2).
# Predicts slightly more samples in Class 1 compared to Logistic Regression.
# - Weaknesses:
# Performs the worst for Class 0 among the three models.
# Heavily biased towards the majority class, with the lowest precision and recall for Class 1 and Class 0.
#
# **ROC AUC**
# - Class 0: AUC = 0.52, near random guessing, indicating almost no discrimination for the minority class.
# - Class 1: AUC = 0.63, lower than Logistic Regression and Random Forest.
# - Class 2: AUC = 0.63, significantly lower than the other models, showing overall weaker performance.

# %% [markdown]
# ##### **Select the best model using the right metric**

# %% [markdown]
# - Best Overall Model: **Random Forest** outperforms the other models in handling both the minority and majority classes, as indicated by its ROC AUC and confusion matrix. It provides better recall and precision for Class 1 and Class 2, though it still struggles with Class 0.
#
# - Moderate Performance: **Logistic Regression** performs well for Class 2 and decently for Class 1, but its recall for Class 0 is very poor.
#
# - Worst Model: **CART Decision Tree** is the least effective, with poor AUC scores across all classes and severe bias towards the majority class.
